# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.random.rand(50)
y=np.random.rand(50)
plt.scatter(x,y,s=50,c='r', marker='*',alpha=0.5)

# %%
plt.show()

# %%
x_val=[1,2,3,4,5]
y_val=[4,6,8,10,12]
plt.plot(x_val,y_val, linestyle='-',linewidth='2',color='b', marker='s', markersize=10, markerfacecolor='r', label='First Line')
#plt.figure() #used to split the two line into two seperate graphs
plt.plot([1,2,3,4,5],[2,3,4,5,6],'gs-', label='Second Line')
#plt.figure()
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('My first plot')
plt.axis([0,6,0,15])
plt.legend()
plt.grid()

# %%
x=np.random.randn(10000)
plt.hist(x,bins=10)
# Out:
# (array([  14.,   87.,  516., 1522., 2723., 2759., 1660.,  572.,  138.,
#            9.]),
#  array([-3.79575385, -3.04427794, -2.29280204, -1.54132613, -0.78985023,
#         -0.03837432,  0.71310159,  1.46457749,  2.2160534 ,  2.9675293 ,
#          3.71900521]),
#  <a list of 10 Patch objects>)

# %%
from sklearn import datasets
df=datasets.load_iris()

# %%
import pandas as pd
data=pd.read_csv('D:\My Personal Documents\Learnings\Data Science\R Codes\Data Sets\Grade.csv')

# %%
#list(data.head(0))
data.median(axis=0)
# Out:
# BOOKS      2.0
# ATTEND    15.0
# GRADE     60.5
# dtype: float64

# %%
plt.scatter(data.BOOKS,data.ATTEND,c='r', marker='*', s=200, label='First')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend()
plt.axis([-2,5,0,30])
# Out:
# [-2, 5, 0, 30]

# %%
plt.boxplot(data.GRADE)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12a9ed5f128>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x12a9ed5f9e8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x12a9ed52f98>],
#  'medians': [<matplotlib.lines.Line2D at 0x12a9ed67278>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12a9ed676a0>],
#  'means': []}

# %%
x1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-04358ba4b61b> in <module>()
# ----> 1 x1
#
# NameError: name 'x1' is not defined
